# %%
#Imporing libraries
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from torch.autograd import Variable
# %matplotlib inline
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.linear_model import LogisticRegression

np.random.seed(1234)
torch.manual_seed(1234)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# path to creative group
dl_path = '/content/drive/MyDrive/Fellowship.ai/Dockers_Outreach/Churn_Analysis/Deep_Learning/'

pd.set_option('display.max_columns', None)
df = pd.read_csv(dl_path+'marketing_data/data.csv', low_memory=False)

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64000 entries, 0 to 63999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   recency        64000 non-null  int64
#  1   history        64000 non-null  float64
#  2   used_discount  64000 non-null  int64
#  3   used_bogo      64000 non-null  int64
#  4   zip_code       64000 non-null  object
#  5   is_referral    64000 non-null  int64
#  6   channel        64000 non-null  object
#  7   offer          64000 non-null  object
#  8   conversion     64000 non-null  int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 4.4+ MB
# None
#    recency  history  used_discount  used_bogo   zip_code  is_referral channel  \
# 0       10   142.44              1          0  Surburban            0   Phone
# 1        6   329.08              1          1      Rural            1     Web
# 2        7   180.65              0          1  Surburban            1     Web
# 3        9   675.83              1          0      Rural            1     Web
# 4        2    45.34              1          0      Urban            0     Web
#
#              offer  conversion
# 0  Buy One Get One           0
# 1         No Offer           0
# 2  Buy One Get One           0
# 3         Discount           0
# 4  Buy One Get One           0

# %%
# let's define churn as a customer who has not purchased in the last 6 months
df['churn'] = df.recency.apply(lambda x: 1 if (x > 6) else 0)
df['treatment'] = df.offer.apply(lambda x: 1 if x != 'No Offer' else 0)

df.treatment.describe()
# Out:
# count    64000.000000
# mean         0.667094
# std          0.471257
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: treatment, dtype: float64

# %%
def offer_conversion(df):
    if (df['offer'] != 'No Offer') & (df['conversion'] == 1):
        return 1
    else:
        return 0

def no_offer_conversion(df):
    if (df['offer'] == 'No Offer') & (df['conversion'] == 1):
        return 1
    else:
        return 0

# %%
#df['convert_with_offer'] = df.apply(offer_conversion, axis=1)
#df['convert_no_offer'] = df.apply(no_offer_conversion, axis=1)

# %%
df.describe(exclude='number').T
# Out:
#           count unique              top   freq
# zip_code  64000      3        Surburban  28776
# channel   64000      3              Web  28217
# offer     64000      3  Buy One Get One  21387

# %%
df.describe(include='number').T
# Out:
#                  count        mean         std    min    25%     50%  \
# recency        64000.0    5.763734    3.507592   1.00   2.00    6.00
# history        64000.0  242.085656  256.158608  29.99  64.66  158.11
# used_discount  64000.0    0.551031    0.497393   0.00   0.00    1.00
# used_bogo      64000.0    0.549719    0.497526   0.00   0.00    1.00
# is_referral    64000.0    0.502250    0.499999   0.00   0.00    1.00
# conversion     64000.0    0.146781    0.353890   0.00   0.00    0.00
# churn          64000.0    0.428359    0.494845   0.00   0.00    0.00
# treatment      64000.0    0.667094    0.471257   0.00   0.00    1.00
#
#                     75%      max
# recency          9.0000    12.00
# history        325.6575  3345.93
# used_discount    1.0000     1.00
# used_bogo        1.0000     1.00
# is_referral      1.0000     1.00
# conversion       0.0000     1.00
# churn            1.0000     1.00
# treatment        1.0000     1.00

# %%
#Defining columns
categorical_columns = list(df.select_dtypes(exclude=['float', 'int']).columns.difference(['Churn']))
numerical_columns = list(df.columns.difference(categorical_columns))
outputs = ['churn']

# %%
train_records
# Out:
# 38400

# %%
#Processing columns

#Numerical
numerical_data = np.stack([df[col].values for col in numerical_columns], 1)
numerical_data = torch.tensor(numerical_data, dtype=torch.float)

#Categorical
for category in categorical_columns:
    df[category] = df[category].astype('category')
    
ch = df['channel'].cat.codes.values
off = df['offer'].cat.codes.values
zc = df['zip_code'].cat.codes.values

categorical_data = np.stack([ch, off, zc], 1)
categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

#Outputs
df[outputs] = df[outputs].astype(int)

outputs = torch.tensor(df[outputs].values).flatten()
outputs = outputs.long()

# %%
categorical_train_data[[19000,  5558, 23286, 15744, 38164, 18472, 10677, 31976, 15198, 29184]][:,0]
# Out:
# tensor([2, 1, 2, 1, 2, 2, 2, 0, 2, 2])

# %%
#Dividing the data
total_records = numerical_data.shape[0]
train_records = int(total_records * .6)
valid_records = int(total_records * .2)
test_records = int(total_records * .2)
numerical_train_data = numerical_data[:train_records]
numerical_valid_data = numerical_data[train_records:train_records+valid_records]
numerical_test_data = numerical_data[train_records+valid_records:total_records]
categorical_train_data = categorical_data[:train_records]
categorical_valid_data = categorical_data[train_records:train_records+valid_records]
categorical_test_data = categorical_data[train_records+valid_records:total_records]
train_outputs = outputs[:train_records]
valid_outputs = outputs[train_records:train_records+valid_records]
test_outputs = outputs[train_records+valid_records:total_records]

# %%
x_categorical[:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-ac278190713e> in <module>()
# ----> 1 x_categorical[:,0]
#
# NameError: name 'x_categorical' is not defined

# %%
from torch.nn.parameter import Parameter
from torch.nn import init
import math

#Creating the Neural Network
class Model(nn.Module):

    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(8, 100)
        self.relu = nn.ReLU(inplace=True)
        self.bn1 = nn.BatchNorm1d(100)
        
        self.weights1 = Parameter(torch.Tensor(1, 112))
        init.kaiming_uniform_(self.weights1, a=math.sqrt(4))
        
        self.weights2 = Parameter(torch.Tensor(1, 112))
        init.kaiming_uniform_(self.weights2, a=math.sqrt(4))
        
        self.bias1 = Parameter(torch.Tensor(1))
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weights1)
        bound = 1 / math.sqrt(fan_in)
        init.uniform_(self.bias1, -bound, bound)
        
        self.bias2 = Parameter(torch.Tensor(1))
        fan_in, _ = init._calculate_fan_in_and_fan_out(self.weights2)
        bound = 1 / math.sqrt(fan_in)
        init.uniform_(self.bias2, -bound, bound)
        
        self.layer1_1 = nn.Embedding(3, 4)
        self.bn1_1 = nn.BatchNorm1d(4)
        self.layer1_2 = nn.Embedding(3, 4)
        self.bn1_2 = nn.BatchNorm1d(4)
        self.layer1_3 = nn.Embedding(3, 4)
        self.bn1_3 = nn.BatchNorm1d(4)
        
        self.layer2 = nn.Linear(112, 112)
        self.bn2 = nn.BatchNorm1d(112)
        
    def forward(self, x_numerical, x_categorical):
        x1 = self.layer1(x_numerical)
        x1 = self.relu(x1)
        x1 = self.bn1(x1)
        
        x1_embedding = self.layer1_1(x_categorical[:,0])
        x1_embedding = self.relu(x1_embedding)
        x1_embedding = self.bn1_1(x1_embedding)
        
        x2_embedding = self.layer1_2(x_categorical[:,1])
        x2_embedding = self.relu(x2_embedding)
        x2_embedding = self.bn1_2(x2_embedding)
        
        x3_embedding = self.layer1_3(x_categorical[:,2])
        x3_embedding = self.relu(x3_embedding)
        x3_embedding = self.bn1_3(x3_embedding)
        
        x_embedding = torch.cat([x1_embedding,x2_embedding,x3_embedding], 1)
                
        x1 = torch.cat([x1 , x_embedding], 1)
        
        x2 = self.layer2(x1)        
        emb = self.relu(x2)
        x2 = self.bn2(emb)
        
        x2_weights1 = torch.mm(x2, self.weights1.t()) + self.bias1
        x2_weights2 = torch.mm(x2, self.weights2.t()) + self.bias2
        
        x3 = torch.cat([x2_weights1, x2_weights2], 1)
                
        return emb, self.weights1, self.weights2, x3

# %%
model = Model()

# %%
df.describe(include='number').T
# Out:
#                  count        mean         std    min    25%     50%  \
# recency        64000.0    5.763734    3.507592   1.00   2.00    6.00
# history        64000.0  242.085656  256.158608  29.99  64.66  158.11
# used_discount  64000.0    0.551031    0.497393   0.00   0.00    1.00
# used_bogo      64000.0    0.549719    0.497526   0.00   0.00    1.00
# is_referral    64000.0    0.502250    0.499999   0.00   0.00    1.00
# conversion     64000.0    0.146781    0.353890   0.00   0.00    0.00
# churn          64000.0    0.428359    0.494845   0.00   0.00    0.00
# treatment      64000.0    0.667094    0.471257   0.00   0.00    1.00
#
#                     75%      max
# recency          9.0000    12.00
# history        325.6575  3345.93
# used_discount    1.0000     1.00
# used_bogo        1.0000     1.00
# is_referral      1.0000     1.00
# conversion       0.0000     1.00
# churn            1.0000     1.00
# treatment        1.0000     1.00

# %%
#===============================================================================================
# Defining churn:loyal weight ratio. churn_percentage=0.7 means churn:loyal weight ratio of 7:3.
# Setting churn_percentage=0.5 to get an unweighted model
#===============================================================================================
## Our data contains about 43% churned customers
churn_percentage = 0.4

#Defining loss function
loss_function = nn.CrossEntropyLoss(weight=torch.Tensor([1-churn_percentage, churn_percentage]))
# loss_function = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
#29 Juni 2020: menambahkan scheduler learning rate
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, 0.9)

# %%
#Training the data
epochs = 2
batch_size = 400
mean_losses_train = []
mean_losses_valid = []
best_loss_valid = np.inf

for i in range(epochs):
    model.train()
    aggregated_losses_train = []
    aggregated_losses_valid = []
    i += 1
    idxs = np.random.permutation(train_records)
    for j in range((train_records//batch_size)):
        start_train = j*batch_size
        end_train = start_train+batch_size
        idxs_batch = idxs[start_train:end_train]

        train, weights1, weights2, train_embed = model(numerical_train_data[idxs_batch], categorical_train_data[idxs_batch]) # yg error 1
        train_loss = loss_function(train_embed, train_outputs[idxs_batch])
        aggregated_losses_train.append(train_loss)

        print(f'iteration: {j:3} loss: {train_loss.item():10.8f}')

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()
        mean_loss_train = torch.mean(torch.stack(aggregated_losses_train))
        
    print(f'epoch: {i:3} mean loss training: {mean_loss_train.item():10.8f}')
    mean_losses_train.append(mean_loss_train)
    
    model.eval()
    with torch.set_grad_enabled(False):
        for k in range((valid_records//batch_size)):
            start_valid = k*batch_size
            end_valid = start_valid+batch_size
            valid, weights1, weights2, valid_embed = model(numerical_valid_data[start_valid:end_valid], categorical_valid_data[start_valid:end_valid])
            valid_loss = loss_function(valid_embed, valid_outputs[start_valid:end_valid])
            aggregated_losses_valid.append(valid_loss)
    mean_loss_valid = torch.mean(torch.stack(aggregated_losses_valid))
    print(f'epoch: {i:3} mean loss validation: {mean_loss_valid:.8f}')
    
    if mean_loss_valid.cpu().numpy()[()] < best_loss_valid:
        best_loss_valid = mean_loss_valid
        torch.save(model.state_dict(), "model_train_cre_{}.pth".format(churn_percentage))
        best_epoch = i        
    
    mean_losses_valid.append(mean_loss_valid)
    scheduler.step()
# Out:
# iteration:   0 loss: 0.00019589
# iteration:   1 loss: 0.00013331
# iteration:   2 loss: 0.00011099
# iteration:   3 loss: 0.00006565
# iteration:   4 loss: 0.00012122
# iteration:   5 loss: 0.00327843
# iteration:   6 loss: 0.00011346
# iteration:   7 loss: 0.00013620
# iteration:   8 loss: 0.00019996
# iteration:   9 loss: 0.00021968
# iteration:  10 loss: 0.00011149
# iteration:  11 loss: 0.00568363
# iteration:  12 loss: 0.00108439
# iteration:  13 loss: 0.00008892
# iteration:  14 loss: 0.00022714
# iteration:  15 loss: 0.00011300
# iteration:  16 loss: 0.00009521
# iteration:  17 loss: 0.00073217
# iteration:  18 loss: 0.00007726
# iteration:  19 loss: 0.00082136
# iteration:  20 loss: 0.00537598
# iteration:  21 loss: 0.00011568
# iteration:  22 loss: 0.00012631
# iteration:  23 loss: 0.00008398
# iteration:  24 loss: 0.00010791
# iteration:  25 loss: 0.00009438
# iteration:  26 loss: 0.00014580
# iteration:  27 loss: 0.00008969
# iteration:  28 loss: 0.00020731
# iteration:  29 loss: 0.00025826
# iteration:  30 loss: 0.00043471
# iteration:  31 loss: 0.00046806
# iteration:  32 loss: 0.00023330
# iteration:  33 loss: 0.00035625
# iteration:  34 loss: 0.00023044
# iteration:  35 loss: 0.00055889
# iteration:  36 loss: 0.00018690
# iteration:  37 loss: 0.00021527
# iteration:  38 loss: 0.00020860
# iteration:  39 loss: 0.00017154
# iteration:  40 loss: 0.00013665
# iteration:  41 loss: 0.00012588
# iteration:  42 loss: 0.00020064
# iteration:  43 loss: 0.00012956
# iteration:  44 loss: 0.00014898
# iteration:  45 loss: 0.00024497
# iteration:  46 loss: 0.00032179
# iteration:  47 loss: 0.00012336
# iteration:  48 loss: 0.00025710
# iteration:  49 loss: 0.00016052
# iteration:  50 loss: 0.00014368
# iteration:  51 loss: 0.00010242
# iteration:  52 loss: 0.00011316
# iteration:  53 loss: 0.00014567
# iteration:  54 loss: 0.00014638
# iteration:  55 loss: 0.00022046
# iteration:  56 loss: 0.00062437
# iteration:  57 loss: 0.00011031
# iteration:  58 loss: 0.00014816
# iteration:  59 loss: 0.00011662
# iteration:  60 loss: 0.00008904
# iteration:  61 loss: 0.00010899
# iteration:  62 loss: 0.00009872
# iteration:  63 loss: 0.00016681
# iteration:  64 loss: 0.00026153
# iteration:  65 loss: 0.00006203
# iteration:  66 loss: 0.00009462
# iteration:  67 loss: 0.00011070
# iteration:  68 loss: 0.00012469
# iteration:  69 loss: 0.00007754
# iteration:  70 loss: 0.00008869
# iteration:  71 loss: 0.00006852
# iteration:  72 loss: 0.00008982
# iteration:  73 loss: 0.00008125
# iteration:  74 loss: 0.00009259
# iteration:  75 loss: 0.00006625
# iteration:  76 loss: 0.00007996
# iteration:  77 loss: 0.00008607
# iteration:  78 loss: 0.00025872
# iteration:  79 loss: 0.00005705
# iteration:  80 loss: 0.00006942
# iteration:  81 loss: 0.00008457
# iteration:  82 loss: 0.00007842
# iteration:  83 loss: 0.00060438
# iteration:  84 loss: 0.00008261
# iteration:  85 loss: 0.00010639
# iteration:  86 loss: 0.00009436
# iteration:  87 loss: 0.00009651
# iteration:  88 loss: 0.00006400
# iteration:  89 loss: 0.00011589
# iteration:  90 loss: 0.00005559
# iteration:  91 loss: 0.00004580
# iteration:  92 loss: 0.00016748
# iteration:  93 loss: 0.00005829
# iteration:  94 loss: 0.00004323
# iteration:  95 loss: 0.00006655
# epoch:   1 mean loss training: 0.00032288
# epoch:   1 mean loss validation: 0.00006668
# iteration:   0 loss: 0.00005630
# iteration:   1 loss: 0.00004860
# iteration:   2 loss: 0.00010664
# iteration:   3 loss: 0.00006640
# iteration:   4 loss: 0.00025158
# iteration:   5 loss: 0.00007163
# iteration:   6 loss: 0.00049811
# iteration:   7 loss: 0.00012533
# iteration:   8 loss: 0.00006190
# iteration:   9 loss: 0.00014820
# iteration:  10 loss: 0.00005337
# iteration:  11 loss: 0.00004779
# iteration:  12 loss: 0.00007673
# iteration:  13 loss: 0.00003846
# iteration:  14 loss: 0.00006783
# iteration:  15 loss: 0.00004501
# iteration:  16 loss: 0.00003843
# iteration:  17 loss: 0.00004433
# iteration:  18 loss: 0.00003907
# iteration:  19 loss: 0.00004381
# iteration:  20 loss: 0.00004395
# iteration:  21 loss: 0.00002351
# iteration:  22 loss: 0.00002520
# iteration:  23 loss: 0.00004907
# iteration:  24 loss: 0.00009771
# iteration:  25 loss: 0.00005863
# iteration:  26 loss: 0.00003044
# iteration:  27 loss: 0.00003074
# iteration:  28 loss: 0.00002993
# iteration:  29 loss: 0.00011062
# iteration:  30 loss: 0.00007149
# iteration:  31 loss: 0.00019623
# iteration:  32 loss: 0.00005798
# iteration:  33 loss: 0.00003843
# iteration:  34 loss: 0.00003392
# iteration:  35 loss: 0.00003280
# iteration:  36 loss: 0.00012305
# iteration:  37 loss: 0.00003845
# iteration:  38 loss: 0.00005159
# iteration:  39 loss: 0.00003037
# iteration:  40 loss: 0.00002856
# iteration:  41 loss: 0.00003331
# iteration:  42 loss: 0.00004344
# iteration:  43 loss: 0.00004715
# iteration:  44 loss: 0.00003713
# iteration:  45 loss: 0.00008566
# iteration:  46 loss: 0.00002644
# iteration:  47 loss: 0.00007342
# iteration:  48 loss: 0.00004035
# iteration:  49 loss: 0.00003726
# iteration:  50 loss: 0.00002141
# iteration:  51 loss: 0.00002782
# iteration:  52 loss: 0.00159041
# iteration:  53 loss: 0.00005770
# iteration:  54 loss: 0.00006011
# iteration:  55 loss: 0.00006583
# iteration:  56 loss: 0.00223855
# iteration:  57 loss: 0.01293905
# iteration:  58 loss: 0.00005333
# iteration:  59 loss: 0.00003549
# iteration:  60 loss: 0.01040985
# iteration:  61 loss: 0.00004663
# iteration:  62 loss: 0.00016459
# iteration:  63 loss: 0.00007325
# iteration:  64 loss: 0.00016193
# iteration:  65 loss: 0.00063543
# iteration:  66 loss: 0.00008682
# iteration:  67 loss: 0.00007631
# iteration:  68 loss: 0.00009608
# iteration:  69 loss: 0.00037378
# iteration:  70 loss: 0.00027914
# iteration:  71 loss: 0.00021647
# iteration:  72 loss: 0.00015085
# iteration:  73 loss: 0.00010093
# iteration:  74 loss: 0.00015137
# iteration:  75 loss: 0.00021065
# iteration:  76 loss: 0.00014756
# iteration:  77 loss: 0.00020412
# iteration:  78 loss: 0.00024210
# iteration:  79 loss: 0.00014447
# iteration:  80 loss: 0.00068686
# iteration:  81 loss: 0.00014210
# iteration:  82 loss: 0.00016214
# iteration:  83 loss: 0.00015687
# iteration:  84 loss: 0.00011075
# iteration:  85 loss: 0.00013431
# iteration:  86 loss: 0.00014041
# iteration:  87 loss: 0.00011705
# iteration:  88 loss: 0.00008315
# iteration:  89 loss: 0.00017710
# iteration:  90 loss: 0.00017703
# iteration:  91 loss: 0.00014367
# iteration:  92 loss: 0.00030579
# iteration:  93 loss: 0.00021684
# iteration:  94 loss: 0.00011005
# iteration:  95 loss: 0.00010782
# epoch:   2 mean loss training: 0.00039157
# epoch:   2 mean loss validation: 0.00013804

# %%
torch.save(model.state_dict(), dl_path+"model_train_cre_{}.pth".format(churn_percentage))

# %%
#Creating predictions
with torch.no_grad():
    valid, valid_weights1, valid_weights2, valid_embed = model(numerical_valid_data, categorical_valid_data)
    valid_loss = loss_function(valid_embed, valid_outputs)
    total_valid_loss = valid_loss
print(f'Loss: {total_valid_loss:.8f}')
# Out:
# Loss: 0.00013796

# %%
from sklearn.metrics import f1_score

valid_val = np.argmax(valid_embed, axis=1)
print(confusion_matrix(valid_outputs, valid_val))
print(classification_report(valid_outputs, valid_val))
print("Accuracy: ", accuracy_score(valid_outputs, valid_val))
print("F1 Score: ", f1_score(valid_outputs, valid_val, average='macro'))
# Out:
# [[7279    0]
#  [   0 5521]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7279
#            1       1.00      1.00      1.00      5521
#
#     accuracy                           1.00     12800
#    macro avg       1.00      1.00      1.00     12800
# weighted avg       1.00      1.00      1.00     12800
#
# Accuracy:  1.0
# F1 Score:  1.0
